# %% [markdown]
# # 🟦 Notebook 15 – Abschlussprojekt: Sortierverfahren entwickeln
# Willkommen in Ihrem Informatik-Notebook!

# %% [markdown]
# ## 📓 Lernziele dieses Notebooks
#
# In diesem Notebook lernen Sie, wie Sie …
#
# - … ein Sortierverfahren **konzipieren**, bevor Sie es programmieren.
# - … ein Verfahren als **Modell** beschreiben (Schritte, Regeln, Daten).
# - … das Modell in Python umsetzen (vgl. *Notebook 05, 10–14*).
# - … Ihr Programm testen und verbessern.
# - … Ergebnisse nachvollziehbar dokumentieren.
#
# ---

# %% [markdown]
# # Abschnitt A – Vom Flussdiagramm zum Python-Programm
#
# Bevor wir mit Python begonnen haben, haben Sie ein **eigenes Sortierverfahren**
# entwickelt und als **Flussdiagramm** festgehalten.
# Dieses Verfahren war unser gemeinsames Vorhaben:
#
# > *Zuerst überlegen wir uns ein Verfahren, dann lernen wir Python –
# > und am Ende setzen wir unser eigenes Verfahren als Programm um.*
#
# Jetzt schließen wir diesen Kreis und setzen Ihr damaliges Konzept **in Python** um.

# %% [markdown]
# ## 📝 Aufgabe 1 – Flussdiagramm als Ausgangsbasis
#
# Nutzen Sie Ihr **Flussdiagramm aus der Phase vor Beginn des Lernpfads** als Grundlage.
#
# - Legen Sie eine Beispiel-Liste an, z. B. `zahlen = [7, 2, 9, 3, 6]`.
# - Notieren Sie kurz, ob Ihr Verfahren **aufsteigend** oder **absteigend** sortiert.

# %%
# 👉 Ihre Lösung zu Aufgabe 1

# %% [markdown]
# ## 📝 Aufgabe 2 – Sortierverfahren in Python umsetzen
#
# Setzen Sie Ihr Sortierverfahren aus dem Flussdiagramm **direkt in Python** um.
#
# - Orientieren Sie sich Schritt für Schritt an Ihrem Diagramm.
# - Testen Sie zwischendurch mit kleinen Listen.

# %%
# 👉 Ihre Lösung zu Aufgabe 2

# %% [markdown]
# ## 📝 Aufgabe 3 – Als Funktion strukturieren
#
# Lagern Sie Ihr Sortierverfahren in eine Funktion aus, z. B. `sortiere(zahlen)`.
#
# - Die Funktion soll eine Liste annehmen.
# - Ob Sie die gleiche Liste verändern oder eine neue sortierte Liste zurückgeben,
#   entscheiden Sie selbst – passend zu Ihrem Verfahren.
#
# Testen Sie die Funktion mit mindestens zwei verschiedenen Listen.

# %%
# 👉 Ihre Lösung zu Aufgabe 3

# %% [markdown]
# ## 🧩 Intensivübungen

# %% [markdown]
# ### Übung 15.1 – Anzahl der Vergleiche zählen
# Erweitern Sie Ihr Sortierverfahren so, dass es zählt, wie viele **Vergleiche** durchgeführt werden.

# %%
# 👉 Übung 15.1

# %% [markdown]
# ### Übung 15.2 – Anzahl der Tausche zählen
# Erweitern Sie Ihr Sortierverfahren so, dass es zählt, wie oft Elemente **getauscht** werden.

# %%
# 👉 Übung 15.2

# %% [markdown]
# ### Übung 15.3 – In die andere Richtung sortieren
# Passen Sie Ihr Verfahren so an, dass es **in die jeweils andere Richtung** sortiert:
# - ursprünglich absteigend → jetzt aufsteigend
# - ursprünglich aufsteigend → jetzt absteigend

# %%
# 👉 Übung 15.3

# %% [markdown]
# # 🏁 Meilenstein 15 – Bekannte Sortierverfahren verstehen und vergleichen
#
# Zum Abschluss beschäftigen Sie sich mit **bekannten Sortierverfahren**, wie sie in der Informatik
# häufig verwendet werden.
#
# ### 🔰 Basis
# - Recherchieren Sie **ein bekanntes Sortierverfahren**, z. B.:
#   - Bubble Sort
#   - Selection Sort
#   - Insertion Sort
# - Beschreiben Sie das Verfahren **in eigenen Worten** (3–5 Sätze).
# - Setzen Sie das Verfahren anschließend **in Python** um.
#
# ### ⭐ Erweiterung
# - Vergleichen Sie das recherchierte Verfahren mit **Ihrem eigenen Sortierverfahren**:
#   - Was ist ähnlich?
#   - Was ist anders?
#   - Welches finden Sie leichter zu verstehen oder zu programmieren?
#
# ### 🚀 Optional
# - Implementieren Sie **zwei verschiedene bekannte Sortierverfahren**.
# - Vergleichen Sie diese untereinander (z. B. Anzahl Vergleiche bei gleicher Liste).
#
# <details>
# <summary>💡 Hinweis anzeigen</summary>
# Orientieren Sie sich bei der Recherche an **Grafiken oder Animationen** zu Sortierverfahren.
# Versuchen Sie anschließend, die Idee mit Schleifen, Vergleichen und Tauschen in Python nachzubauen.
# </details>

# %%
# 👉 Ihr Meilenstein-Programm

# %%
# 👉 Ihr Meilenstein-Programm

# %% [markdown]
# # 🧾 Zusammenfassung dieses Notebooks
#
# ## 🎯 Wichtige Inhalte
# - Algorithmen werden zuerst als Modell geplant und dann umgesetzt.
# - Sortierverfahren beruhen auf Vergleichen, Tauschen und Wiederholung.
# - Testfälle helfen, Korrektheit zu prüfen.
# - Zählen von Vergleichen/Tauschen gibt Einblick in Effizienz.
# - Strukturierung mit Funktionen macht Projekte übersichtlich.
#
# 📚 Glossar
# - **Algorithmus**: Schritt-für-Schritt-Anleitung zur Problemlösung.
# - **Modell**: vereinfachte Darstellung eines Verfahrens.
# - **Sortierverfahren**: Algorithmus zum Ordnen einer Liste.
# - **Testfall**: gezieltes Beispiel zur Überprüfung von Programmen.
# - **Effizienz**: Aufwand eines Algorithmus (z. B. Anzahl Vergleiche).
