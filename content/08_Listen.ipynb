# %% [markdown]
# # 🟦 Notebook 8 – Grundlagen zu Listen in Python
# Willkommen in Ihrem Informatik-Notebook!

# %% [markdown]
# ## 📓 Lernziele dieses Notebooks
#
# In diesem Notebook lernen Sie, wie Sie …
#
# - … Listen erstellen und Elemente lesen/schreiben.
# - … über Listen **iterieren** und Werte auswerten.
# - … wichtige Listen-Methoden (`append`, `remove`, `sort`) anwenden.
# - … häufige Fehler (Indexfehler, leere Listen) vermeiden.
#
# ---

# %% [markdown]
# # Abschnitt A – Grundlagen des Themas
#
# Zur Erinnerung (vgl. *Notebook 05 – Schleifen*): Listen und Schleifen gehören zusammen. Listen speichern geordnete Mehrfachwerte, auf die per Index zugegriffen wird (`0`-basiert).

# %% [markdown]
# ## 📝 Aufgabe 1 – Liste erstellen & zugreifen
#
# Erstellen Sie eine Liste mit fünf Lieblingsspeisen. Geben Sie das **erste**, **mittlere** und **letzte** Element aus und ändern Sie ein Element.
#
# ⭐ Erweiterung (fakultativ)
# - Fügen Sie ein neues Element am **Anfang** der Liste ein.
#
# <details>
# <summary>💡 Hinweis anzeigen</summary>
#
# <details>
# <summary>Grundlagen</summary>
# Zugriff: `liste[0]`, `liste[-1]`; Einfügen z. B. mit `insert(0, wert)`.
# </details>
#
# <details>
# <summary>Länge</summary>
# `len(liste)` hilft beim Finden des mittleren Elements.
# </details>
#
# </details>

# %%
# 👉 Ihre Lösung zu Aufgabe 1

# %% [markdown]
# ## 📝 Aufgabe 2 – Listen-Methoden
#
# Lesen Sie wiederholt Wörter ein (Abbruch `stop`) und speichern Sie sie in einer Liste. Geben Sie am Ende die **sortierte** Liste aus.
#
# ⭐ Erweiterung (fakultativ)
# - Entfernen Sie **Dubletten** (einfacher Ansatz).
#
# <details>
# <summary>💡 Hinweis anzeigen</summary>
#
# <details>
# <summary>Methoden</summary>
# `append`, `sort`, `remove`; Dubletten-Prüfung mit `if wort not in liste:`
# </details>
#
# <details>
# <summary>Fehlerfälle</summary>
# Leere Liste: sortieren/ausgeben sinnvoll behandeln.
# </details>
#
# </details>

# %%
# 👉 Ihre Lösung zu Aufgabe 2

# %% [markdown]
# # Abschnitt B – Vertiefung & Hauptaufgaben
#
# Wir werten Listen aus und kombinieren sie mit Schleifen.

# %% [markdown]
# ## 📝 Aufgabe 3 – Notenliste auswerten
#
# Lesen Sie eine Notenliste (z. B. `2, 3, 1, 4` als Eingabe, dann Umwandlung) und berechnen Sie **Durchschnitt**, **Minimum** und **Maximum**.
#
# ⭐ Erweiterung (fakultativ)
# - Zählen Sie die **Häufigkeit** jeder Note (1–6).
#
# <details>
# <summary>💡 Hinweis anzeigen</summary>
#
# <details>
# <summary>Eingabe zerlegen</summary>
# `text.split(",")` und per Schleife in `int` umwandeln.
# </details>
#
# <details>
# <summary>Auswertung</summary>
# `min(l)`, `max(l)`, Durchschnitt = `sum(l)/len(l)` (leer prüfen).
# </details>
#
# </details>

# %%
# 👉 Ihre Lösung zu Aufgabe 3

# %% [markdown]
# ## 📝 Aufgabe 4 – Filtern
#
# Lesen Sie eine Liste von Ganzzahlen ein und geben Sie nur die **geraden** Zahlen aus.
#
# ⭐ Erweiterung (fakultativ)
# - Erstellen Sie eine zweite Liste mit den **Quadraten** aller Zahlen.
#
# <details>
# <summary>💡 Hinweis anzeigen</summary>
#
# <details>
# <summary>Filtern</summary>
# `x % 2 == 0` prüft auf gerade Zahlen.
# </details>
#
# <details>
# <summary>Iteration</summary>
# Schleife über die Liste, neue Liste sammeln.
# </details>
#
# </details>

# %%
# 👉 Ihre Lösung zu Aufgabe 4

# %% [markdown]
# ## 🧩 Intensivübungen
#
# ### Übung 5.1 – Liste ohne Duplikate
# Schreiben Sie ein Programm, das Eingaben sammelt und eine **Liste ohne Duplikate** erzeugt.

# %%
# 👉 Übung 5.1

# %% [markdown]
# ### Übung 5.2 – In-place umkehren
# Schreiben Sie ein Programm, das eine Liste **in-place** umkehrt.

# %%
# 👉 Übung 5.2

# %% [markdown]
# ### Übung 5.3 – Häufigkeit zählen
# Schreiben Sie ein Programm, das zählt, wie oft ein bestimmtes Element in einer Liste vorkommt.

# %%
# 👉 Übung 5.3

# %% [markdown]
# ### Übung 5.4 – Abwechselnd mischen
# Schreiben Sie ein Programm, das zwei Listen **abwechselnd** zusammenführt (A1, B1, A2, B2, …).

# %%
# 👉 Übung 5.4

# %% [markdown]
# ### Übung 5.5 – Zweitgrößtes Element
# Schreiben Sie ein Programm, das das **zweitgrößte** Element in einer Liste findet.

# %%
# 👉 Übung 5.5

# %% [markdown]
# # 🏁 Meilenstein 6 – Einfaches Notenbuch
#
# Erstellen Sie ein kleines Notenbuch: Noten einlesen, **Durchschnitt** berechnen, **beste/schlechteste** Note anzeigen, optional sortiert ausgeben.
#
# ### 🔰 Basis
# - Eingabe, Liste aufbauen, Kennwerte berechnen.
#
# ### ⭐ Erweiterung
# - Häufigkeiten je Note zählen und Tabelle ausgeben.
#
# ### 🚀 Optional
# - Eine einfache **Menüführung** für mehrere Aktionen (Hinzufügen/Anzeigen/Beenden).
#
# <details>
# <summary>💡 Hinweis anzeigen</summary>
# Achten Sie auf leere Liste (Division durch 0). Nutzen Sie string → int-Umwandlung sorgfältig.
# </details>

# %%
# 👉 Ihr Meilenstein-Programm

# %% [markdown]
# # 🧾 Zusammenfassung dieses Notebooks
#
# ## 🎯 Wichtige Inhalte
# - Listen aufbauen und sicher bearbeiten.
# - Iteration über Listen für Auswertungen.
# - Typische Methoden gezielt nutzen.
# - Robuste Eingaben verarbeiten.
#
# 📚 Glossar
# - **Liste**: geordnete, veränderliche Sequenz.
# - **Index**: Position eines Elements in der Liste.
# - **Iteration**: Durchlaufen einer Datenstruktur.
# - **Mutieren**: Ändern von Daten in-place.
# - **Häufigkeit**: Anzahl der Vorkommen eines Wertes.
