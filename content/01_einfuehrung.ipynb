# %% [raw]
#   ___             ___      _____          ____   ____
#  |_ _|  _ __     / |_     | ____|        |___ \ | ___|
#   | |  | '_  \   |  _/    |  _|    _____   __) ||___ \
#   | |  | | | |   | |      | |___  |_____| / __/  ___) |
#  |___| |_| |_|   |_|      |_____|        |____| |____/

# %% [markdown]
# # Lieber Informatik-Kurs, willkommen zu unserem Jupyterlite!
# Ich möchte euch interaktives Lernmaterial zum Lernen der Konzepte der Programmierung und Algorithmen bereitstellen. Ich hoffe, ihr werdet Freude daran finden, sobald wir richtig loslegen. JupyterLite ist eine moderne Umgebung, die vollständig in deinem Browser läuft – ohne dass du etwas installieren musst. Sie basiert auf der Idee der Jupyter Notebooks.
# ## Hier ein paar wichtige Dinge zum Start:
#
# <ol><font color="blue">
#     <li> Du fragst dich vielleicht, was ist ein "Jupyter Notebook"?</font>
#     Du befindest dich gerade in einem. Die ".ipynb"-Dateien sind eigenständige Jupyter Notebooks.
#     Ein Jupyter Notebook ist kein normales Dokument. Es besteht aus verschiedenen Zellen:
#     Text-Zellen (Markdown): Hier stehen Erklärungen, Bilder und Aufgaben (wie dieser Text hier).
#     Code-Zellen: Hier schreibst du echten Programmcode (wir verwenden vorerst nur Python).
#
#  <li><font color="blue">Was ist Python?</font>
#
# Python ist bekannt als vergleichsweise einfacher zu erlernende Programmiersprache, die dabei gleichzeitig sehr vielseitig ist. Sie eignet sich hervorragend für Webentwicklung, Datenanalyse, Automatisierung und Künstliche Intelligenz. Sie eignet sich also sehr gut für den Einstieg und um sein Wissen später zu vertiefen. Falls ihr schon einen Vorgeschmack bekommen wollt, wie sie aussieht und was die grundsätzlichen Konzepte sind, empfehle ich euch z.B. https://www.w3schools.com/python/default.asp</li>
# <li><font color="blue">Die wichtigste Tastenkombination</font></li>
# Um eine Zelle "auszuführen" (also den Text anzuzeigen oder den Code zu starten), klicke in die Zelle und drücke:
# Shift + Enter
# (Alternativ kannst du auch den "Run"-Button ▶ in der oberen Leiste nutzen).</li>
#
# <li><font color="blue">Sprache ändern</font></li>
# Ich habe das Sprachpaket für die deutsche Sprache auf dem Urverzeichnis installiert. Ihr könnt also die Sprache oben in den Reitern unter "Settings"->"Language" auf Deutsch ändern. Leider handelt es sich dabei jedoch nur um eine Teilübersetzung, viele Wörter sind trotzdem noch Englisch. Wenn ihr euch mit Englisch schon wohlfühlt oder mehr Englisch lernen wollt, dann bleibt ruhig bei Englisch. Das ist ohnehin sehr wichtig, um die Anleitungen externer Websites zu verstehen, weil diese auch oft nur in Englisch verfügbar sind.</li>
#
# <li><font color="blue">Achtung: Wo wird gespeichert?</font>
#
# JupyterLite speichert deine Arbeit standardmäßig im lokalen Speicher deines Browsers.
# Vorteil: Du kannst einfach die Seite schließen und später weitermachen.<font color="red">Wichtig: Wenn du den Browserverlauf löschst oder an einem anderen Tablet oder Computer arbeitest, sind deine Fortschritte weg! Darum:</font></li>
# <li><font color="blue">itsLearning</font>
#
# Lädt jeder von euch bitte mindestens einmal pro Woche euren Fortschritt herunter. Das könnt ihr unter "Datei"->"Download". Dabei bekommt ihr ein Workbook als Datei zurück. Der Fortschritt und der aktuelle Zustand in diesem Workbook wird gespeichert. Dann ladet ihr eure bearbeiteten, heruntergeladenen Workbooks in der Aufgabe des aktuellen itsLearning Plans hoch. Für die erste Abgabe haben wir nur ein Workbook, das sollte also schaffbar sein. Für diese Woche ist die <font color="red">Frist für die Einreichung der Workbooks freitags 18:00 Uhr.</font> Wir können nächstes Mal darüber reden, ob ihr lieber z.B. noch das Wochenende dazu haben wollt. Aber keine Panik, ihr bekommt während der Doppelstunde bereits Zeit, am aktuellen Workbook zu arbeiten.</li>
# <li><font color="blue">Spaß dabei haben</font>
#
# Um in der Informatik zu lernen ist es wichtig, Interesse und Freude an der Thematik zu entwickeln. Das gilt nicht nur fürs Programmieren, sondern den gesamten Themenbereich. Leider schaffen wir nicht annäherend alles abzudecken, aber das ist auch fast unmöglich Dafür ist es wichtig kleine Erfolge zu feiern und auch mal dran zu bleiben wenn es hart wird.</li></ol>

# %% [markdown]
# Deine erste Aufgabe: Der "Check-in"
# Klicke in die untere Code-Zelle, tippe deinen Namen zwischen die Anführungszeichen und drücke Shift + Enter.

# %%
name = "Dein Name"

# %%
print(f"Hallo {name}, ich wünsche dir eine gute Woche!")
# Out:
# Hallo The King, ich wünsche dir eine gute Woche!

# %% [markdown]
# <font color="blue">name ist dabei eine Variable vom Typ String. Variable habt ihr bestimmt schon von gehört. Nächste Woche schauen wir uns dann an, was wir mit Variablen in Python machen können. Dann wird es auch weniger Text lesen und mehr selber machen und ausprobieren.</font>
