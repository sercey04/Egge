# %% [markdown]
# #<div style="padding: 5px; border: 5px solid #0077b6;">
# ## Aufgabe
# Schreibe in dem folgenden Phyton-Programm, welchen Wert der folgenden Summe berechnet:
#     $$\sum_{i=1}^{100} i := 1+ \dots + 100$$
